# %% [markdown]
# 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title

# %%
import matplotlib.pyplot as plt
import numpy as np

x_points = np.array([0, 10])
y_points = np.array([0, 10])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Graph")
plt.plot(x_points,y_points)

# %% [markdown]
# 2. Write a Python program to draw a line using given axis values with suitable label in the x axis
#    , y axis and a title

# %%
x_points = np.array([10, 100])
y_points = np.array([100, 10])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Graph")
plt.plot(x_points,y_points)

# %% [markdown]
# 3. Write a Python program to draw a line using given axis values taken from a text file, with
# suitable label in the x axis, y axis and a title.
# Test Data:
# test.txt
# 1 2
# 2 4
# 3 1

# %%
x_points = []
y_points = []
with open("line.txt", "r") as file:
    for line in file:
        x, y = map(int, line.split())
        x_points.append(x)
        y_points.append(y)
x_points = np.array(x_points)
y_values = np.array(y_points)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Graph from text file")
plt.plot(x_points,y_points)

# %% [markdown]
# 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between
# October 3, 2016 to October 7, 2016.
# Sample Financial data (fdata.csv):
# Date,Open,High,Low,Close
# 03-10-16,774.25,776.065002,769.5,772.559998
# 04-10-16,776.030029,778.710022,772.890015,776.429993
# 05-10-16,779.309998,782.070007,775.650024,776.469971
# 06-10-16,779,780.47998,775.539978,776.859985
# 07-10-16,779.659973,779.659973,770.75,775.080017

# %%
import pandas as pd

file_path = "fdata.csv" 
df = pd.read_csv(file_path)
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%y')
plt.plot(df['Date'], df['Open'])
plt.plot(df['Date'], df['Close'])
plt.plot(df['Date'], df['High'])

plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("Alphabet Inc. Stock Prices")
plt.grid()
plt.show()

# %% [markdown]
# 5. Write a Python program to plot two or more lines on same plot with suitable legends of each
# line.

# %%
x1_points = np.array([10, 100])
y1_points = np.array([100, 10])
x2_points = np.array([20, 200])
y2_points = np.array([200, 20])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple lines on the same plot")
plt.plot(x1_points,y1_points,label="Line 1")
plt.plot(x2_points,y2_points,label="Line 2")
plt.legend()
plt.show()

# %% [markdown]
# 6. Write a Python program to plot two or more lines with legends, different widths and colors.

# %%
x1_points = np.array([10, 100])
y1_points = np.array([100, 10])
x2_points = np.array([20, 200])
y2_points = np.array([200, 20])
x3_points = np.array([30, 300])
y3_points = np.array([300, 30])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple lines on the same plot")
plt.plot(x1_points, y1_points, label="Line 1", linewidth=2, color = 'r')
plt.plot(x2_points, y2_points, label="Line 2", linewidth=4, color = 'b')
plt.plot(x3_points, y3_points, label="Line 3", linewidth=1, color = 'g')
plt.legend()
plt.show()

# %% [markdown]
# 7. Write a Python program to plot two or more lines with different styles

# %%
x1_points = np.array([10, 100])
y1_points = np.array([100, 10])
x2_points = np.array([20, 200])
y2_points = np.array([200, 20])
x3_points = np.array([30, 300])
y3_points = np.array([300, 30])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple lines on the same plot")
plt.plot(x1_points, y1_points, label="Line 1", linewidth=2, color = 'r', linestyle='dotted')
plt.plot(x2_points, y2_points, label="Line 2", linewidth=4, color = 'b', linestyle='dashed')
plt.plot(x3_points, y3_points, label="Line 3", linewidth=1, color = 'g', linestyle='solid')
plt.legend()
plt.show()

# %% [markdown]
# 8. Write a Python program to plot two or more lines and set the line markers.

# %%
x1_points = np.array([10, 100])
y1_points = np.array([100, 10])
x2_points = np.array([20, 200])
y2_points = np.array([200, 20])
x3_points = np.array([30, 300])
y3_points = np.array([300, 30])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple lines on the same plot")
plt.plot(x1_points, y1_points, label="Line 1", linewidth=2, color = 'r', linestyle='dotted', marker = 'o')
plt.plot(x2_points, y2_points, label="Line 2", linewidth=4, color = 'b', linestyle='dashed', marker = 'x')
plt.plot(x3_points, y3_points, label="Line 3", linewidth=1, color = 'g', linestyle='solid', marker = 's')
plt.legend()
plt.show()

# %% [markdown]
# 9. Write a Python program to display the current axis limits values and set new axis values.

# %%
x1_points = np.array([10, 100])
y1_points = np.array([100, 10])
x2_points = np.array([20, 200])
y2_points = np.array([200, 20])
x3_points = np.array([30, 300])
y3_points = np.array([300, 30])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple lines on the same plot")
plt.plot(x1_points, y1_points, label="Line 1", linewidth=2, color = 'r', linestyle='dotted', marker = 'o')
plt.plot(x2_points, y2_points, label="Line 2", linewidth=4, color = 'b', linestyle='dashed', marker = 'x')
plt.plot(x3_points, y3_points, label="Line 3", linewidth=1, color = 'g', linestyle='solid', marker = 's')
current_limits = plt.axis()
print("Current axis limits:", current_limits)
plt.xlim(0, 350)
plt.ylim(0, 350)
current_limits = plt.axis()
print("Current axis limits:", current_limits)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple lines on the same plot")
plt.plot(x1_points, y1_points, label="Line 1", linewidth=2, color = 'r', linestyle='dotted', marker = 'o')
plt.plot(x2_points, y2_points, label="Line 2", linewidth=4, color = 'b', linestyle='dashed', marker = 'x')
plt.plot(x3_points, y3_points, label="Line 3", linewidth=1, color = 'g', linestyle='solid', marker = 's')
plt.legend()
plt.show()
# Out:
# Current axis limits: (np.float64(-4.5), np.float64(314.5), np.float64(-4.5), np.float64(314.5))
# Current axis limits: (np.float64(0.0), np.float64(350.0), np.float64(0.0), np.float64(350.0))

# %% [markdown]
# 10. Write a Python program to plot quantities which have an x and y position.

# %%
plt.plot(x1_points, y1_points, label="Line 1", linewidth=2, color = 'r', linestyle='', marker = 'o', markersize = 2)
plt.plot(x2_points, y2_points, label="Line 2", linewidth=4, color = 'b', linestyle='', marker = 'x', markersize = 8)
plt.plot(x3_points, y3_points, label="Line 3", linewidth=1, color = 'g', linestyle='', marker = 's', markersize = 4)
plt.legend()
plt.show()

# %% [markdown]
# 11. Write a Python program to plot several lines with different format styles in one command
# using arrays.

# %%
plt.plot(x1_points, y1_points, 'ro-', x2_points, y2_points, 'bs--', x3_points, y3_points, 'gD:')
plt.legend(["Line 1", "Line 2", "Line 3"])
plt.show()

# %% [markdown]
# 12. Write a Python program to create multiple types of charts

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].plot(x1_points, y1_points, 'ro-', label="Line 1")
axes[0].plot(x2_points, y2_points, 'bs--', label="Line 2")
axes[0].plot(x3_points, y3_points, 'gD:', label="Line 3")
axes[0].set_title("Line Chart")
axes[0].legend()
axes[1].bar(x1_points, y1_points, color='r', label="Bar 1")
axes[1].bar(x2_points, y2_points, color='b', label="Bar 2", alpha = 0.7)
axes[1].bar(x3_points, y3_points, color='g', label="Bar 3")
axes[1].set_title("Bar Chart")
axes[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 13. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# linestyle -, width .5. and color blue.
# Date,Close
# 03-10-16,772.559998
# 04-10-16,776.429993
# 05-10-16,776.469971
# 06-10-16,776.859985
# 07-10-16,775.080017

# %%
import pandas as pd


df = pd.read_csv("fdata.csv")
dates = df["Date"]
closing_values = df["Close"]
plt.plot(dates, closing_values, marker='o', linestyle='-', color='r', label="Closing Value")
plt.grid(linestyle='-', linewidth=0.5, color='blue')
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("Alphabet Inc. Closing Prices (Oct 3 - Oct 7, 2016)")
plt.legend()
plt.show()

# %% [markdown]
# 14. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn
# off ticks.

# %%
fig, ax = plt.subplots()
ax.minorticks_on() 
ax.plot(dates, closing_values, marker='o', linestyle='-', color='r', label="Closing Value")
ax.grid(which='major', linestyle='-', linewidth=0.8, color='blue')
ax.grid(which='minor', linestyle=':', linewidth=0.5, color='gray')
ax.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False)
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("Alphabet Inc. Closing Prices (Oct 3 - Oct 7, 2016)")
plt.legend()
plt.show()

# %% [markdown]
# 15. Write a Python program to create multiple plots.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].plot(x1_points, y1_points, 'ro-', label="Line 1")
axes[0].plot(x2_points, y2_points, 'bs--', label="Line 2")
axes[0].plot(x3_points, y3_points, 'gD:', label="Line 3")
axes[0].set_title("Line Chart")
axes[0].legend(loc="upper right")
axes[1].bar(x1_points, y1_points, color='r', label="Bar 1")
axes[1].bar(x2_points, y2_points, color='b', label="Bar 2", alpha = 0.7)
axes[1].bar(x3_points, y3_points, color='g', label="Bar 3")
axes[1].set_title("Bar Chart")
axes[1].legend(loc="upper right")
plt.tight_layout()
plt.show()
